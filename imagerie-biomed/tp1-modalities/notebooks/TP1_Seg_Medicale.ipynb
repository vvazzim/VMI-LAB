# %% [markdown]
# # Imagerie Bioméd — TP1 (squelette)
#
# > 📒 **Colab-first** : ce notebook est un *squelette*. Ajoute les cellules d'exécution dans Colab.
#
# ## ✅ À compléter
# - Objectifs du TP
# - Jeux de données (Drive/URL)
# - Plan d'expérience
# - Métriques et checkpoints (si DL)
# - Résultats & analyse
